# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %%
ratings = pd.read_csv('tourism_rating.csv')
places = pd.read_csv('tourism_with_id.csv')
users = pd.read_csv('user.csv')
packages = pd.read_csv('package_tourism.csv')

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   User_Id        10000 non-null  int64
#  1   Place_Id       10000 non-null  int64
#  2   Place_Ratings  10000 non-null  int64
# dtypes: int64(3)
# memory usage: 234.5 KB

# %%
# Pivot table (User-Item matrix)
user_item_matrix = ratings.pivot_table(index='User_Id', columns='Place_Id', values='Place_Ratings')

# %%
# Fill NaN with 0
user_item_filled = user_item_matrix.fillna(0)

# User-User similarity
user_similarity = cosine_similarity(user_item_filled)
user_sim_df = pd.DataFrame(user_similarity, index=user_item_filled.index, columns=user_item_filled.index)

# %%
def get_similar_users(user_id, user_sim_df, top_n=5):
    # Get similarity scores for the user with all others
    sim_scores = user_sim_df.loc[user_id]
    # Remove self similarity
    sim_scores = sim_scores.drop(user_id)
    # Sort and get top N similar users
    top_users = sim_scores.sort_values(ascending=False).head(top_n)
    return top_users

def recommend_places(user_id, user_item_filled, user_sim_df, top_n=5):
    # Get top similar users
    similar_users = get_similar_users(user_id, user_sim_df)
    
    # Weighted sum of ratings from similar users
    weighted_ratings = np.zeros(user_item_filled.shape[1])
    sim_sum = 0
    for other_user, similarity in similar_users.items():
        weighted_ratings += similarity * user_item_filled.loc[other_user].values
        sim_sum += similarity

    if sim_sum == 0:
        print("No similar users found.")
        return []

    # Average weighted ratings
    weighted_avg_ratings = weighted_ratings / sim_sum

    # Places the user has already rated
    user_rated = user_item_filled.loc[user_id]
    already_rated = user_rated[user_rated > 0].index.tolist()

    # Recommend places not rated by the user
    recommendations = []
    for idx, place_id in enumerate(user_item_filled.columns):
        if place_id not in already_rated:
            recommendations.append((place_id, weighted_avg_ratings[idx]))

    # Sort recommendations by predicted rating
    recommendations = sorted(recommendations, key=lambda x: x[1], reverse=True)

    return recommendations[:top_n]

# Example usage
user_id = user_item_filled.index[0]  # replace with any valid user ID
top_recommendations = recommend_places(user_id, user_item_filled, user_sim_df, top_n=5)

print(f"Top recommendations for User {user_id}:")
for place_id, score in top_recommendations:
    place_name = places.loc[places['Place_Id'] == place_id, 'Place_Name'].values[0]
    print(f"{place_name} (Place_Id: {place_id}) - Score: {score:.2f}")
# Out:
# Top recommendations for User 1:
# Museum Kebangkitan Nasional (Place_Id: 63) - Score: 1.86
# Kebun Teh Nglinggo (Place_Id: 166) - Score: 1.71
# Dusun Bambu (Place_Id: 220) - Score: 1.53
# Taman Miniatur Kereta Api (Place_Id: 327) - Score: 1.50
# Pantai Sepanjang (Place_Id: 184) - Score: 1.47

# %%
places[places['City']=='Semarang']
# Out:
#      Place_Id                                        Place_Name  \
# 334       335                                Candi Gedong Songo
# 335       336                                   Grand Maerakaca
# 336       337                                   Kampung Pelangi
# 337       338                                       Lawang Sewu
# 338       339                               Sam Poo Kong Temple
# 339       340                     Desa Wisata Lembah Kalipancur
# 340       341                   Hutan Wisata Tinjomoyo Semarang
# 341       342                                    Taman Kasmaran
# 342       343                                     Pantai Baruna
# 384  Kampung Batik Semarang merupakan salah satu ka...         Budaya
# 385  Terletak di lereng Gunung Ungaran bagian utara...     Cagar Alam
# 386  Goa Kreo Semarang yang berada di ibukota Jawa ...     Cagar Alam
# 387  Objek wisata alam memang sangat cocok dikunjun...     Cagar Alam
# 388  Di Indonesia, Brown Canyon adalah sebuah bekas...     Cagar Alam
# 389  Perlu diketahui, watu simbar ini merupakan lok...     Cagar Alam
# 390  Di taman bunga Setiya Aji Flower Farm kita bis...     Cagar Alam
#
#          City   Price  Rating  Time_Minutes  \
# 334  Semarang   10000     4.5           NaN
# 335  Semarang   15000     4.4           NaN
# 336  Semarang    3000     4.3          30.0
# 337  Semarang   10000     4.6           NaN
# 338  Semarang   35000     4.5           NaN
# 339  Semarang       0     3.9          90.0
# 340  Semarang    3000     4.3           NaN
# 341  Semarang    3000     4.5          90.0
# 342  Semarang    3000     4.0           NaN
# 343  Semarang    3000     4.1           NaN
# 344  Semarang   10000     4.7           NaN
# 345  Semarang       0     4.6          45.0
# 346  Semarang       0     4.4          45.0
# 347  Semarang   20000     4.7           NaN
# 348  Semarang    5000     4.3          90.0
# 349  Semarang    5000     4.0          90.0
# 350  Semarang   50000     4.4           NaN
# 351  Semarang       0     4.6           NaN
# 352  Semarang       0     4.7           NaN
# 353  Semarang   10000     4.6          90.0
# 354  Semarang   75000     4.6           NaN
# 355  Semarang  150000     4.4         180.0
# 356  Semarang   10000     4.1          45.0
# 357  Semarang       0     4.1           NaN
# 358  Semarang   25000     4.3          90.0
# 359  Semarang    5000     4.1           NaN
# 360  Semarang   10000     4.1           NaN
# 361  Semarang   15000     4.4           NaN
# 362  Semarang    5000     3.4           NaN
# 363  Semarang   80000     4.2          60.0
# 364  Semarang    2500     4.3           NaN
# 365  Semarang   20000     4.4         150.0
# 366  Semarang    7000     4.3           NaN
# 367  Semarang    3000     4.5           NaN
# 368  Semarang    7500     4.4          20.0
# 369  Semarang    5000     4.2          60.0
# 370  Semarang   25000     4.3          90.0
# 371  Semarang    2000     4.8           NaN
# 372  Semarang   10000     4.5          60.0
# 373  Semarang    6000     4.4           NaN
# 374  Semarang       0     4.7          90.0
# 375  Semarang   30000     4.5          30.0
# 376  Semarang   35000     4.5           NaN
# 377  Semarang       0     4.2          60.0
# 378  Semarang    5000     4.3           NaN
# 379  Semarang       0     4.7           NaN
# 380  Semarang       0     4.7           NaN
# 381  Semarang  200000     4.3          90.0
# 382  Semarang       0     4.4          60.0
# 383  Semarang       0     4.5          90.0
# 384  Semarang       0     4.4          45.0
# 385  Semarang    9000     4.4           NaN
# 386  Semarang    5500     4.3          60.0
# 387  Semarang   25000     4.4           NaN
# 388  Semarang       0     4.2          30.0
# 389  Semarang    5000     4.1          45.0
# 390  Semarang    7500     4.1          45.0
#
#                                           Coordinate       Lat        Long  \
# 334  {'lat': -7.209886700000002, 'lng': 110.3421119} -7.209887  110.342112
# 335          {'lat': -6.9605225, 'lng': 110.3863941} -6.960522  110.386394
# 336  {'lat': -6.988881200000001, 'lng': 110.4083781} -6.988881  110.408378
# 337          {'lat': -6.9839099, 'lng': 110.4104342} -6.983910  110.410434
# 338   {'lat': -6.996236599999999, 'lng': 110.398122} -6.996237  110.398122
# 339          {'lat': -7.0205245, 'lng': 110.3754605} -7.020524  110.375461
# 340          {'lat': -7.0296837, 'lng': 110.3999611} -7.029684  110.399961
# 341          {'lat': -6.9909404, 'lng': 110.4065932} -6.990940  110.406593
# 342  {'lat': -6.945105199999999, 'lng': 110.3982398} -6.945105  110.398240
# 343           {'lat': -6.948877, 'lng': 110.3893285} -6.948877  110.389329
# 344  {'lat': -6.968773100000001, 'lng': 110.4319505} -6.968773  110.431950
# 345  {'lat': -6.992350699999998, 'lng': 110.4201162} -6.992351  110.420116
# 346  {'lat': -6.987793600000001, 'lng': 110.4172262} -6.987794  110.417226
# 347  {'lat': -6.998475900000001, 'lng': 110.4106468} -6.998476  110.410647
# 348  {'lat': -6.968561800000001, 'lng': 110.3459696} -6.968562  110.345970
# 349          {'lat': -6.9486402, 'lng': 110.4102923} -6.948640  110.410292
# 350  {'lat': -6.968406400000001, 'lng': 110.4261995} -6.968406  110.426199
# 351  {'lat': -6.968348799999999, 'lng': 110.4274767} -6.968349  110.427477
# 352          {'lat': -6.9681728, 'lng': 110.4278262} -6.968173  110.427826
# 353     {'lat': -6.967499999999999, 'lng': 110.4282} -6.967500  110.428200
# 354          {'lat': -7.1945903, 'lng': 110.3733583} -7.194590  110.373358
# 355  {'lat': -7.280726200000001, 'lng': 110.4595539} -7.280726  110.459554
# 356  {'lat': -7.115796899999999, 'lng': 110.4217966} -7.115797  110.421797
# 357  {'lat': -7.018778199999999, 'lng': 110.2937134} -7.018778  110.293713
# 358  {'lat': -7.225504099999998, 'lng': 110.3463166} -7.225504  110.346317
# 359  {'lat': -7.358096300000001, 'lng': 110.4210681} -7.358096  110.421068
# 360  {'lat': -7.214158199999999, 'lng': 110.3769541} -7.214158  110.376954
# 361          {'lat': -7.2854929, 'lng': 110.4321671} -7.285493  110.432167
# 362          {'lat': -6.9545687, 'lng': 110.3600951} -6.954569  110.360095
# 363          {'lat': -7.0218894, 'lng': 110.4383345} -7.021889  110.438334
# 364          {'lat': -7.0370499, 'lng': 110.3477586} -7.037050  110.347759
# 365   {'lat': -7.132106000000001, 'lng': 110.394523} -7.132106  110.394523
# 366          {'lat': -7.3126613, 'lng': 110.3746785} -7.312661  110.374679
# 367   {'lat': -7.267539000000001, 'lng': 110.418076} -7.267539  110.418076
# 368  {'lat': -7.259886099999998, 'lng': 110.4025602} -7.259886  110.402560
# 369          {'lat': -7.2706462, 'lng': 110.4103291} -7.270646  110.410329
# 370  {'lat': -7.253109599999999, 'lng': 110.4264512} -7.253110  110.426451
# 371  {'lat': -7.255236400000001, 'lng': 110.3991897} -7.255236  110.399190
# 372  {'lat': -7.264598899999997, 'lng': 110.4046017} -7.264599  110.404602
# 373  {'lat': -7.395606000000001, 'lng': 110.4517727} -7.395606  110.451773
# 374          {'lat': -6.9681399, 'lng': 110.4278611} -6.968140  110.427861
# 375   {'lat': -6.974992299999999, 'lng': 110.424954} -6.974992  110.424954
# 376  {'lat': -7.215692300000001, 'lng': 110.3649392} -7.215692  110.364939
# 377  {'lat': -7.267820100000002, 'lng': 110.4483217} -7.267820  110.448322
# 378          {'lat': -7.2721621, 'lng': 110.4698457} -7.272162  110.469846
# 379  {'lat': -7.135070499999999, 'lng': 110.4088131} -7.135071  110.408813
# 380          {'lat': -6.9843485, 'lng': 110.4093207} -6.984349  110.409321
# 381  {'lat': -7.253900499999999, 'lng': 110.4414953} -7.253901  110.441495
# 382  {'lat': -7.038803199999999, 'lng': 110.4215576} -7.038803  110.421558
# 383  {'lat': -7.029097399999999, 'lng': 110.3775382} -7.029097  110.377538
# 384  {'lat': -6.968882100000001, 'lng': 110.4318692} -6.968882  110.431869
# 385   {'lat': -7.166297100000002, 'lng': 110.381068} -7.166297  110.381068
# 386          {'lat': -7.0372113, 'lng': 110.3476164} -7.037211  110.347616
# 387   {'lat': -7.129806599999999, 'lng': 110.388832} -7.129807  110.388832
# 388          {'lat': -7.0565164, 'lng': 110.4862531} -7.056516  110.486253
# 389  {'lat': -7.096707899999999, 'lng': 110.3900517} -7.096708  110.390052
# 390          {'lat': -7.2241813, 'lng': 110.3782661} -7.224181  110.378266
#
#      Unnamed: 11  Unnamed: 12
# 334          NaN          335
# 335          NaN          336
# 336          NaN          337
# 337          NaN          338
# 338          NaN          339
# 339          NaN          340
# 340          NaN          341
# 341          NaN          342
# 342          NaN          343
# 343          NaN          344
# 344          NaN          345
# 345          NaN          346
# 346          NaN          347
# 347          NaN          348
# 348          NaN          349
# 349          NaN          350
# 350          NaN          351
# 351          NaN          352
# 352          NaN          353
# 353          NaN          354
# 354          NaN          355
# 355          NaN          356
# 356          NaN          357
# 357          NaN          358
# 358          NaN          359
# 359          NaN          360
# 360          NaN          361
# 361          NaN          362
# 362          NaN          363
# 363          NaN          364
# 364          NaN          365
# 365          NaN          366
# 366          NaN          367
# 367          NaN          368
# 368          NaN          369
# 369          NaN          370
# 370          NaN          371
# 371          NaN          372
# 372          NaN          373
# 373          NaN          374
# 374          NaN          375
# 375          NaN          376
# 376          NaN          377
# 377          NaN          378
# 378          NaN          379
# 379          NaN          380
# 380          NaN          381
# 381          NaN          382
# 382          NaN          383
# 383          NaN          384
# 384          NaN          385
# 385          NaN          386
# 386          NaN          387
# 387          NaN          388
# 388          NaN          389
# 389          NaN          390
# 390          NaN          391

# %%
places.iloc[184-1]
# Out:
# Place_Id                                                      184
# Place_Name                                       Pantai Sepanjang
# Description     Siapa sangka, ternyata Yogyakarta pun punya “K...
# Category                                                   Bahari
# City                                                   Yogyakarta
# Price                                                       10000
# Rating                                                        4.4
# Time_Minutes                                                120.0
# Coordinate        {'lat': -8.136665599999999, 'lng': 110.5659962}
# Lat                                                     -8.136666
# Long                                                   110.565996
# Unnamed: 11                                                   NaN
# Unnamed: 12                                                   184
# Name: 183, dtype: object
