# %%
import pandas as pd

# %%
places = pd.read_csv('../../dataset/places_v2.csv')
ratings = pd.read_csv('../../dataset/ratings.csv')
# df = df.dropna(axis=1, how="all")
# df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %%
places.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 441 entries, 0 to 440
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Place_Id       441 non-null    int64
#  1   Place_Name     441 non-null    object
#  2   Description    441 non-null    object
#  3   Category       441 non-null    object
#  4   City           441 non-null    object
#  5   Price          441 non-null    int64
#  6   Rating         441 non-null    float64
#  7   Time_Minutes   208 non-null    float64
#  8   Coordinate     441 non-null    object
#  9   Lat            441 non-null    float64
#  10  Long           441 non-null    float64
#  11  Unnamed: 11    0 non-null      float64
#  12  Unnamed: 12    441 non-null    int64
#  13  Working_Hours  159 non-null    object
# dtypes: float64(5), int64(3), object(6)
# memory usage: 48.4+ KB

# %%
places[places['Place_Id'] == 259]
# Out:
#      Place_Id                            Place_Name  \
# 262       259  Monumen Perjuangan Rakyat Jawa Barat
#
#                                            Description Category     City  \
# 262  Monumen Perjuangan Rakyat Jawa Barat (Monju) a...   Budaya  Bandung
#
#      Price  Rating  Time_Minutes                               Coordinate  \
# 262      0     4.5          45.0  {'lat': -6.8934327, 'lng': 107.6185513}
#
#           Lat        Long  Unnamed: 11  Unnamed: 12  \
# 262 -6.893433  107.618551          NaN          259
#
#                                          Working_Hours
# 262  Kamis: 08.00–16.00 | Jumat: 08.00–16.00 | Sabt...

# %%
places['Place_Id'].nunique()
# Out:
# 437

# %%
ratings['Place_Id'].nunique()
# Out:
# 437

# %%
df[['Coordinate', 'Lat', 'Long']]
# Out:
#                                           Coordinate       Lat        Long
# 0            {'lat': -6.1753924, 'lng': 106.8271528} -6.175392  106.827153
# 1    {'lat': -6.137644799999999, 'lng': 106.8171245} -6.137645  106.817125
# 2    {'lat': -6.125312399999999, 'lng': 106.8335377} -6.125312  106.833538
# 3    {'lat': -6.302445899999999, 'lng': 106.8951559} -6.302446  106.895156
# 4               {'lat': -6.12419, 'lng': 106.839134} -6.124190  106.839134
# ..                                               ...       ...         ...
# 432          {'lat': -7.4338593, 'lng': 112.7199058} -7.433859  112.719906
# 433  {'lat': -7.291346799999999, 'lng': 112.7398218} -7.291347  112.739822
# 434          {'lat': -7.2752955, 'lng': 112.7549381} -7.275296  112.754938
# 435  {'lat': -7.294330299999999, 'lng': 112.7617534} -7.294330  112.761753
# 436          {'lat': -7.2420758, 'lng': 112.7368158} -7.242076  112.736816
#
# [437 rows x 3 columns]

# %%
# # Hitung jumlah Place_Name unik
# unique_place_names = df['Place_Name'].nunique()
# print(f"Jumlah Place_Name yang unik: {unique_place_names}\n")

# # Cetak semua kategori unik
# categories = df['Category'].unique()
# print(f"Kategori unik: {categories}\n")

# # Untuk setiap kategori, cetak jumlah data dan 10 data acak (hanya id dan Place_Name)
# for category in categories:
#     subset = df[df['Category'] == category]
#     print(f"Kategori: {category}")
#     print(f"Jumlah data: {len(subset)}")
#     print("10 data acak (id dan Place_Name):")
#     print(subset[['Place_Id', 'Place_Name']].sample(n=min(10, len(subset)), random_state=42))
#     print("="*80)
# Out:
# Jumlah Place_Name yang unik: 437
#
# Kategori unik: ['Budaya' 'Taman Hiburan' 'Cagar Alam' 'Bahari' 'Pusat Perbelanjaan'
#  'Tempat Ibadah']
#
# Kategori: Budaya
# Jumlah data: 117
# 10 data acak (id dan Place_Name):
#      Place_Id                                         Place_Name
# 114       115                                   Monumen Sanapati
# 17         18                              Museum Bank Indonesia
# 146       147                    Bentara Budaya Yogyakarta (BBY)
# 106       107                                  Bangsal Pagelaran
# 38         39  Museum Macan (Modern and Contemporary Art in N...
# 337       338                                        Lawang Sewu
# 258       259               Monumen Perjuangan Rakyat Jawa Barat
# 374       375                                 Kota Lama Semarang
# 98         99                           Kampung Wisata Kadipaten
# 39         40                          Galeri Nasional Indonesia
# ...
# Kategori: Taman Hiburan
# ...

# %%
# unique_places = df['Place_Name'].unique()

# # Mencetak setiap nama tempat yang unik
# for place in unique_places:
#     print(place)
# Out:
# Monumen Nasional
# Kota Tua
# Dunia Fantasi
# Taman Mini Indonesia Indah (TMII)
# Atlantis Water Adventure
# Taman Impian Jaya Ancol
# Kebun Binatang Ragunan
# Ocean Ecopark
# Pelabuhan Marina
# Pulau Tidung
# Pulau Bidadari
# Pulau Pari
# Pulau Pramuka
# Pulau Pelangi
# Pasar Seni
# Jembatan Kota Intan
# Museum Fatahillah
# Museum Bank Indonesia
# Kidzania
# Museum Taman Prasasti
# Museum Wayang
# Masjid Istiqlal
# Gereja Katedral
# Museum Nasional
# Pasar Tanah Abang
# Pecinan Glodok
# Sea World
# Wisata Agro Edukatif Istana Susu Cibugary
# Wisata Kuliner Pecenongan
# Taman Menteng
# Wisata Alam Mangrove Angke
# Setu Babakan
# Taman Suropati
# Pasar Taman Puring
# Grand Indonesia Mall
# Skyrink - Mall Taman Anggrek
# Bumi Perkemahan Cibubur
# Istana Negara Republik Indonesia
# Museum Macan (Modern and Contemporary Art in Nusantara)
# Galeri Nasional Indonesia
# Museum Bahari Jakarta
# Museum Seni Rupa dan Kramik
# The Escape Hunt
# Monumen Selamat Datang
# ...

# %%
df.tail()
# Out:
#      Place_Id                                 Place_Name  \
# 432       433                        Museum Mpu Tantular
# 433       434                              Taman Bungkul
# 434       435           Taman Air Mancur Menari Kenjeran
# 435       436               Taman Flora Bratang Surabaya
# 436       437  Gereja Perawan Maria Tak Berdosa Surabaya
#
#                                            Description       Category  \
# 432  Museum Negeri Mpu Tantular adalah sebuah museu...         Budaya
# 433  Taman Bungkul adalah taman wisata kota yang te...  Taman Hiburan
# 434  Air mancur menari atau dancing fountain juga a...  Taman Hiburan
# 435  Taman Flora adalah salah satu taman kota di Su...  Taman Hiburan
# 436  Gereja Katolik Kelahiran Santa Perawan Maria m...  Tempat Ibadah
#
#          City  Price  Rating  Time_Minutes  \
# 432  Surabaya   2000     4.4          45.0
# 433  Surabaya      0     4.6           NaN
# 434  Surabaya      0     4.4          45.0
# ...

# %%
# duplicates = df[df.duplicated(keep=False)]

# print("Duplicated rows:")
# print(duplicates)
# Out:
# Duplicated rows:
# Empty DataFrame
# Columns: [Place_Id, Place_Name, Description, Category, City, Price, Rating, Time_Minutes, Coordinate, Lat, Long]
# Index: []
